# %%
from functionTp6 import *
import wave

# %%
#====================Sirene de la police===================================
# CREATION DES 2 NOTES DE LA SIRENE
note1 = note(435,1,0.5)     # Fréquence: 435Hz
                            # Amplitude: 1 
                            # Durée 0.5s
                            
note2 = note(580,1,0.5)


#===============ASSEMBLAGE DE LA SUITE DE NOTE=============================
#L'argument de la fonction assemblerLesNotes s'écrit comme ceci: (note1, note2,...)

sirene = assemblerLesNotes( (note1,note2,note1) ) 

#=================== ECOUTER LA SUITE DE NOTE===============================
entendreLeSon(sirene)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# 1

# %%
import numpy as np
from IPython.display import Audio,display
from functionTp6 import *
import time
from scipy.io import wavfile
samplerate, data = wavfile.read('accompaniment.wav')
dataMono = data[:,0]/np.abs(np.max(data[:,0]))
fe=44100  
amplitude = 0.3
duréeCourt = 0.32
solcourt = note(392,amplitude,duréeCourt)
sollong = note(392,amplitude,1)
blanc = note(440,0,0.4)
la = note (440,amplitude,duréeCourt)
sib = note(466,amplitude,duréeCourt)
do = note (523,amplitude,duréeCourt)
blanc2 = note(440,0,0.48)
son = assemblerLesNotes([blanc,solcourt,sollong,solcourt,sollong,sib, do, sib, la, solcourt, solcourt,blanc2])
son = assemblerLesNotes([son,son,son,son,son,son])
l1 = np.shape(son)
l2 = np.shape(dataMono)
print(l1,l2)
sonfinal = superposeSon(dataMono,son)
display(Audio(sonfinal, rate=fe,autoplay=True))
#display(Audio(dataMono, rate=fe,autoplay=True))
# Out:
# (1440134,) (1444864,)
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
impor
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 impor
#
# NameError: name 'impor' is not defined
